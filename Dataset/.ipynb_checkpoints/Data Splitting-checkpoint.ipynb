# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
training_data_path = 'train_data.csv'
validation_data_path = 'val_data.csv'
testing_data_path = 'test_data.csv'

training_data = pd.read_csv(training_data_path)
validation_data = pd.read_csv(validation_data_path)
testing_data = pd.read_csv(testing_data_path)

print("Training Data Head:")
training_data.head().T

print("Validation Data Head:")
validation_data.head().T

print("Testing Data Head:")
testing_data.head().T
# Out:
# Training Data Head:
# Validation Data Head:
# Testing Data Head:
#                                         0       1      2       3      4
# Likes Received (per post)          971.00  506.00  776.0  170.00   52.0
# Comments Received (per post)       115.00  417.00  105.0  191.00  395.0
# Peer Comparison Frequency (1-10)     1.00    8.00    6.0    3.00    9.0
# Socioeconomic Status                 1.00    2.00    2.0    2.00    0.0
# Education Level                      1.00    2.00    1.0    2.00    0.0
# Body Image Impact (1-10)             6.00    4.00    6.0    2.00    4.0
# Sleep Quality Impact (1-10)          8.00    7.00    7.0    8.00    6.0
# Self Confidence Impact (1-10)        2.00    5.00    5.0    1.00    1.0
# Cyberbullying Experience (1-10)      9.00    4.00    8.0    3.00    8.0
# Anxiety Levels (1-10)                6.00    3.00    1.0    3.00    1.0
# Age Category                         0.00    1.00    2.0    1.00    0.0
# Total Social Interaction          1187.00  932.00  946.0  474.00  583.0
# Usage Intensity                      0.00    0.00    1.0    0.00    0.0
# Usage Anxiety Interaction           11.63   12.34    0.0    9.35   21.9
# Social_Anxiety_Category              1.00    2.00    0.0    1.00    2.0

# %%
# Check distributions of a numerical feature like 'Daily SM Usage (hrs)'
plt.figure(figsize=(12, 6))

# Plot distributions across the training, validation, and test sets
sns.histplot(training_data['Cyberbullying Experience (1-10)'], color='blue', label='Training Set', kde=True, stat='density')
sns.histplot(validation_data['Cyberbullying Experience (1-10)'], color='orange', label='Validation Set', kde=True, stat='density')
sns.histplot(testing_data['Cyberbullying Experience (1-10)'], color='purple', label='Test Set', kde=True, stat='density')

plt.legend()
plt.title('Comparison of Cyberbullying Experience (1-10) Distribution Across Sets')
plt.xlabel('Cyberbullying Experience (1-10)')
plt.ylabel('Density')
plt.show()

# %%
print("Validation Data Summary:")
validation_data.describe().T
# Out:
# Validation Data Summary:
#                                     count        mean         std   min  \
# Likes Received (per post)         68183.0  504.253758  285.936267  10.0
# Comments Received (per post)      68183.0  249.189827  144.545961   0.0
# Peer Comparison Frequency (1-10)  68183.0    5.494346    2.875405   1.0
# Socioeconomic Status              68183.0    0.998035    0.817009   0.0
# Education Level                   68183.0    1.506593    1.117623   0.0
# Body Image Impact (1-10)          68183.0    5.490738    2.872558   1.0
# Sleep Quality Impact (1-10)       68183.0    5.507047    2.863764   1.0
# Self Confidence Impact (1-10)     68183.0    5.486837    2.873186   1.0
# Cyberbullying Experience (1-10)   68183.0    5.489433    2.872651   1.0
# Anxiety Levels (1-10)             68183.0    5.511726    2.875789   1.0
# Age Category                      68183.0    0.997903    0.894584   0.0
# Total Social Interaction          68183.0  902.757227  331.569537  44.0
# Usage Intensity                   68183.0    0.655882    0.866605   0.0
# Usage Anxiety Interaction         68183.0    6.888637    6.927118   0.0
# Social_Anxiety_Category           68183.0    1.100670    0.831081   0.0
#
#                                     25%     50%     75%     max
# Likes Received (per post)         255.0  503.00   752.0   999.0
# Comments Received (per post)      124.0  249.00   374.0   499.0
# Peer Comparison Frequency (1-10)    3.0    5.00     8.0    10.0
# Socioeconomic Status                0.0    1.00     2.0     2.0
# Education Level                     1.0    2.00     3.0     3.0
# Body Image Impact (1-10)            3.0    6.00     8.0    10.0
# Sleep Quality Impact (1-10)         3.0    6.00     8.0    10.0
# Self Confidence Impact (1-10)       3.0    5.00     8.0    10.0
# Cyberbullying Experience (1-10)     3.0    6.00     8.0    10.0
# Anxiety Levels (1-10)               3.0    6.00     8.0    10.0
# Age Category                        0.0    1.00     2.0     2.0
# Total Social Interaction          652.0  903.00  1153.0  1774.0
# Usage Intensity                     0.0    0.00     2.0     2.0
# Usage Anxiety Interaction           0.0    5.31    11.1    24.0
# Social_Anxiety_Category             0.0    1.00     2.0     2.0

# %%
print("Testing Data Summary:")
testing_data.describe().T
# Out:
# Testing Data Summary:
#                                     count        mean         std   min  \
# Likes Received (per post)         68184.0  504.052974  286.062915  10.0
# Comments Received (per post)      68184.0  249.057272  144.488119   0.0
# Peer Comparison Frequency (1-10)  68184.0    5.512041    2.869518   1.0
# Socioeconomic Status              68184.0    1.003007    0.816434   0.0
# Education Level                   68184.0    1.504473    1.118164   0.0
# Body Image Impact (1-10)          68184.0    5.499692    2.864746   1.0
# Sleep Quality Impact (1-10)       68184.0    5.506570    2.873336   1.0
# Self Confidence Impact (1-10)     68184.0    5.494104    2.866945   1.0
# Cyberbullying Experience (1-10)   68184.0    5.492388    2.874252   1.0
# Anxiety Levels (1-10)             68184.0    5.525226    2.867536   1.0
# Age Category                      68184.0    0.997551    0.893740   0.0
# Total Social Interaction          68184.0  902.940265  331.316947  33.0
# Usage Intensity                   68184.0    0.652191    0.865648   0.0
# Usage Anxiety Interaction         68184.0    6.863297    6.899903   0.0
# Social_Anxiety_Category           68184.0    1.098982    0.828104   0.0
#
#                                     25%    50%      75%     max
# Likes Received (per post)         256.0  504.0   752.00   999.0
# Comments Received (per post)      124.0  248.0   374.00   499.0
# Peer Comparison Frequency (1-10)    3.0    6.0     8.00    10.0
# Socioeconomic Status                0.0    1.0     2.00     2.0
# Education Level                     1.0    2.0     3.00     3.0
# Body Image Impact (1-10)            3.0    5.0     8.00    10.0
# Sleep Quality Impact (1-10)         3.0    6.0     8.00    10.0
# Self Confidence Impact (1-10)       3.0    5.0     8.00    10.0
# Cyberbullying Experience (1-10)     3.0    5.0     8.00    10.0
# Anxiety Levels (1-10)               3.0    6.0     8.00    10.0
# Age Category                        0.0    1.0     2.00     2.0
# Total Social Interaction          651.0  903.0  1154.00  1778.0
# Usage Intensity                     0.0    0.0     2.00     2.0
# Usage Anxiety Interaction           0.0    5.3    11.03    24.0
# Social_Anxiety_Category             0.0    1.0     2.00     2.0

# %%
print("Training Data Summary:")
training_data.describe().T
# Out:
# Training Data Summary:
#                                      count        mean         std   min  \
# Likes Received (per post)         204549.0  504.140465  285.803325  10.0
# Comments Received (per post)      204549.0  249.637314  144.352426   0.0
# Peer Comparison Frequency (1-10)  204549.0    5.498013    2.871872   1.0
# Socioeconomic Status              204549.0    0.998299    0.816646   0.0
# Education Level                   204549.0    1.499074    1.117781   0.0
# Body Image Impact (1-10)          204549.0    5.504055    2.869844   1.0
# Sleep Quality Impact (1-10)       204549.0    5.508221    2.868639   1.0
# Self Confidence Impact (1-10)     204549.0    5.498810    2.869543   1.0
# Cyberbullying Experience (1-10)   204549.0    5.496512    2.867667   1.0
# Anxiety Levels (1-10)             204549.0    5.509853    2.874192   1.0
# Age Category                      204549.0    0.998846    0.894059   0.0
# Total Social Interaction          204549.0  903.192301  331.585298  20.0
# Usage Intensity                   204549.0    0.653105    0.865967   0.0
# Usage Anxiety Interaction         204549.0    6.868050    6.911581   0.0
# Social_Anxiety_Category           204549.0    1.099570    0.829776   0.0
#
#                                     25%    50%      75%     max
# Likes Received (per post)         257.0  504.0   752.00   999.0
# Comments Received (per post)      124.0  250.0   374.00   499.0
# Peer Comparison Frequency (1-10)    3.0    6.0     8.00    10.0
# Socioeconomic Status                0.0    1.0     2.00     2.0
# Education Level                     1.0    1.0     2.00     3.0
# Body Image Impact (1-10)            3.0    5.0     8.00    10.0
# Sleep Quality Impact (1-10)         3.0    6.0     8.00    10.0
# Self Confidence Impact (1-10)       3.0    6.0     8.00    10.0
# Cyberbullying Experience (1-10)     3.0    5.0     8.00    10.0
# Anxiety Levels (1-10)               3.0    6.0     8.00    10.0
# Age Category                        0.0    1.0     2.00     2.0
# Total Social Interaction          651.0  902.0  1155.00  1785.0
# Usage Intensity                     0.0    0.0     2.00     2.0
# Usage Anxiety Interaction           0.0    5.3    11.03    24.0
# Social_Anxiety_Category             0.0    1.0     2.00     2.0

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=training_data)
plt.title('Class Distribution in Training Data')
plt.show()

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=validation_data)
plt.title('Class Distribution in Validation Data')
plt.show()

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=testing_data)
plt.title('Class Distribution in Testing Data')
plt.show()
