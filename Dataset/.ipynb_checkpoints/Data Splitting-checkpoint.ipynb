# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
training_data_path = 'training_data.csv'
#validation_data_path = 'validation_data.csv'
#testing_data_path = 'testing_data.csv'

# Load the data for each set
training_data = pd.read_csv(training_data_path)
validation_data = pd.read_csv(validation_data_path)
testing_data = pd.read_csv(testing_data_path)

# Now you can check or process the data
print("Training Data Head:")
training_data.head()

print("Validation Data Head:")
validation_data.head()

print("Testing Data Head:")
testing_data.head()
# Out:
# Training Data Head:
# Validation Data Head:
# Testing Data Head:
#    Country Age Group  Gender  Urban/Rural  Daily SM Usage (hrs)  \
# 0        8     56-65       0            1                  4.54
# 1        0     46-55       0            1                  6.51
# 2        6     56-65       0            1                 10.16
# 3        3     36-45       1            0                  4.30
# 4       10     56-65       0            0                 11.13
#
#   Most Used SM Platform  Frequency of SM Use  Likes Received (per post)  \
# 0               Twitter                    0                      142.0
# 1             Instagram                    0                      605.0
# 2                TikTok                    2                      321.0
# 3             Instagram                    1                      313.0
# 4                TikTok                    1                      962.0
#
#    Comments Received (per post)  Shares Received (per post)  ...  \
# ...

# %%
# Check distributions of a numerical feature like 'Daily SM Usage (hrs)'
plt.figure(figsize=(12, 6))

# Plot distributions across the training, validation, and test sets
sns.histplot(training_data['Daily SM Usage (hrs)'], color='blue', label='Training Set', kde=True, stat='density')
sns.histplot(validation_data['Daily SM Usage (hrs)'], color='orange', label='Validation Set', kde=True, stat='density')
sns.histplot(testing_data['Daily SM Usage (hrs)'], color='purple', label='Test Set', kde=True, stat='density')

plt.legend()
plt.title('Comparison of Daily SM Usage (hrs) Distribution Across Sets')
plt.xlabel('Daily SM Usage (hrs)')
plt.ylabel('Density')
plt.show()

# %%
print("Validation Data Summary:")
validation_data.describe()
# Out:
# Validation Data Summary:
#             Country        Gender   Urban/Rural  Daily SM Usage (hrs)  \
# count  68184.000000  68184.000000  68184.000000          68184.000000
# mean       4.995835      0.504253      0.500587              6.242474
# std        3.165858      0.499986      0.500003              3.325488
# min        0.000000      0.000000      0.000000              0.500000
# 25%        2.000000      0.000000      0.000000              3.360000
# 50%        5.000000      1.000000      1.000000              6.230000
# 75%        8.000000      1.000000      1.000000              9.140000
# max       10.000000      1.000000      1.000000             12.000000
#
#        Frequency of SM Use  Likes Received (per post)  \
# count         68184.000000               68184.000000
# mean              1.502728                 503.095330
# std               1.116201                 285.960791
# min               0.000000                  10.000000
# ...

# %%
print("Testing Data Summary:")
testing_data.describe()
# Out:
# Testing Data Summary:
#             Country        Gender   Urban/Rural  Daily SM Usage (hrs)  \
# count  54547.000000  54547.000000  54547.000000          54547.000000
# mean       4.990870      0.495701      0.497278              6.244265
# std        3.158331      0.499986      0.499997              3.320091
# min        0.000000      0.000000      0.000000              0.500000
# 25%        2.000000      0.000000      0.000000              3.360000
# 50%        5.000000      0.000000      0.000000              6.230000
# 75%        8.000000      1.000000      1.000000              9.120000
# max       10.000000      1.000000      1.000000             12.000000
#
#        Frequency of SM Use  Likes Received (per post)  \
# count         54547.000000               54547.000000
# mean              1.492199                 502.440336
# std               1.116598                 285.965220
# min               0.000000                  10.000000
# ...

# %%
# Summary statistics for numerical variables
print("Training Data Summary:")
training_data.describe()
# Out:
# Training Data Summary:
#              Country         Gender    Urban/Rural  Daily SM Usage (hrs)  \
# count  218185.000000  218185.000000  218185.000000         218185.000000
# mean        4.996132       0.501121       0.499251              6.246028
# std         3.160639       0.500000       0.500001              3.315679
# min         0.000000       0.000000       0.000000              0.500000
# 25%         2.000000       0.000000       0.000000              3.380000
# 50%         5.000000       1.000000       0.000000              6.250000
# 75%         8.000000       1.000000       1.000000              9.110000
# max        10.000000       1.000000       1.000000             12.000000
#
#        Frequency of SM Use  Likes Received (per post)  \
# count        218185.000000              218185.000000
# mean              1.499168                 504.900176
# std               1.118493                 285.833470
# min               0.000000                  10.000000
# ...

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=training_data)
plt.title('Class Distribution in Training Data')
plt.show()

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=validation_data)
plt.title('Class Distribution in Validation Data')
plt.show()

# %%
# If the target variable is 'target', replace with your actual target column name
plt.figure(figsize=(6, 4))
sns.countplot(x='Anxiety Levels (1-10)', data=testing_data)
plt.title('Class Distribution in Testing Data')
plt.show()
